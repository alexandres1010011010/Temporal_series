# %% [markdown]
# # Tabela de vendas

# %%
import pandas as pd

# %%
df = pd.read_csv("Base de Dados - Questionário.xlsx - Sheet1.csv", sep = ",")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32757 entries, 0 to 32756
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  0 non-null      float64
#  2   Unnamed: 2  32754 non-null  object
#  3   Unnamed: 3  32754 non-null  object
#  4   Unnamed: 4  32754 non-null  object
#  5   Unnamed: 5  32754 non-null  object
#  6   Unnamed: 6  32754 non-null  object
#  7   Unnamed: 7  32754 non-null  object
#  8   Unnamed: 8  32754 non-null  object
#  9   Unnamed: 9  32754 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 2.5+ MB

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 1                        Unnamed: 2  \
# 0         NaN         NaN                               NaN
# 1         NaN         NaN                               NaN
# 2         NaN         NaN                               NaN
# 3         NaN         NaN                                ID
# 4         NaN         NaN  80260d682079b6090c8285b398c50d97
#
#                           Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                                NaN        NaN        NaN        NaN
# 1                                NaN        NaN        NaN        NaN
# 2                                NaN        NaN        NaN        NaN
# 3                          ProductID   ClientID   Discount  UnitPrice
# 4  002552c0663708129c0019cc97552d7d3      14001       0,08      249,2
#
#   Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0        NaN        NaN         NaN
# 1        NaN        NaN         NaN
# 2        NaN        NaN         NaN
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0  Unnamed: 1                        Unnamed: 2  \
# 32752         NaN         NaN  b155e2a8589d40bc9c0381ee48e3204f
# 32753         NaN         NaN  abb71d0110c4be1a1a0c52f929cab4a3
# 32754         NaN         NaN  db9a034f34174edd577b9f64cc982952
# 32755         NaN         NaN  ee00fa5093eb96d8573403b382fb60a8
# 32756         NaN         NaN  56c87d433bb46c7862e35e791b1907fa
#
#                               Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 32752  002ec297b1b00fb9dde7ee6ac24b67712      28694       0,08      218,4
# 32753  002d4ea7c04739c130bb74d7e7cd16943      28694       0,08        210
# 32754  001795ec6f1b187d37335e1c4704762e3      28694       0,08      148,4
# 32755  002ec297b1b00fb9dde7ee6ac24b67713      28694        0,1      218,4
# 32756  0009406fd7479715e4bef61dd91f24622      28695        0,1      254,8
#
#       Unnamed: 7 Unnamed: 8  Unnamed: 9
# 32752          1          4   12/2/2018
# 32753          1          4   12/5/2018
# ...

# %%
df = df.dropna(axis=1, how='all')

# %%
df
# Out:
#                              Unnamed: 2                         Unnamed: 3  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                    ID                          ProductID
# 4      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# ...                                 ...                                ...
# 32752  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32753  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32754  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32755  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32756  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
# ...

# %%
df = df.dropna(axis=0, how='all')

# %%
df
# Out:
#                              Unnamed: 2                         Unnamed: 3  \
# 3                                    ID                          ProductID
# 4      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 5      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 6      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 7      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# ...                                 ...                                ...
# 32752  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32753  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32754  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32755  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32756  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
# ...

# %%
df.shape
# Out:
# (32754, 8)

# %%
df.iloc[0, list(range(df.shape[1]))]
# Out:
# Unnamed: 2           ID
# Unnamed: 3    ProductID
# Unnamed: 4     ClientID
# Unnamed: 5     Discount
# Unnamed: 6    UnitPrice
# Unnamed: 7     Quantity
# Unnamed: 8      StoreID
# Unnamed: 9         Date
# Name: 3, dtype: object

# %%
lista_de_nomes = df.iloc[0, list(range(df.shape[1]))]

# %%
lista_de_nomes = [lista_de_nomes[i] for i in range(lista_de_nomes.shape[0])]

# %%
lista_de_nomes
# Out:
# ['ID',
#  'ProductID',
#  'ClientID',
#  'Discount',
#  'UnitPrice',
#  'Quantity',
#  'StoreID',
#  'Date']

# %%
df = df.iloc[range(1, df.shape[0]), list(range(df.shape[1]))]

# %%
df.columns = lista_de_nomes

# %%
df
# Out:
#                                      ID                          ProductID  \
# 4      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 5      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 6      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 7      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 8      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# ...                                 ...                                ...
# 32752  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32753  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32754  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32755  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32756  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
#       ClientID Discount UnitPrice Quantity StoreID        Date
# ...

# %%
df.index = range(df.shape[0])

# %%
df.dtypes
# Out:
# ID           object
# ProductID    object
# ClientID     object
# Discount     object
# UnitPrice    object
# Quantity     object
# StoreID      object
# Date         object
# dtype: object

# %%
df
# Out:
#                                      ID                          ProductID  \
# 0      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# ...                                 ...                                ...
# 32748  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32749  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32752  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
#       ClientID Discount UnitPrice Quantity StoreID        Date
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"])
df["Discount"] = df["Discount"].replace(',', '.', regex=True)
df["Discount"] = pd.to_numeric(df["Discount"])
df["UnitPrice"] = df["UnitPrice"].replace(',', '.', regex=True)
df["UnitPrice"] = pd.to_numeric(df["UnitPrice"])
df["Quantity"] = pd.to_numeric(df["Quantity"])
df["ClientID"] = pd.to_numeric(df["ClientID"])
df["StoreID"] = pd.to_numeric(df["StoreID"])
#df["ID"] = pd.to_numeric(df["ID"])
#df["ProductID"] = pd.to_numeric(df["ProductID"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32753 entries, 0 to 32752
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         32753 non-null  object
#  1   ProductID  32753 non-null  object
#  2   ClientID   32753 non-null  int64
#  3   Discount   32753 non-null  float64
#  4   UnitPrice  32753 non-null  float64
#  5   Quantity   32753 non-null  int64
#  6   StoreID    32753 non-null  int64
#  7   Date       32753 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 2.0+ MB

# %%
# Assuming your sales table is named 'sales_df'

# Group by the product ID and calculate aggregate statistics
grouped_df = df.groupby('ProductID').agg({
    'Quantity': 'sum',
    'Discount': 'mean',
    'UnitPrice': 'mean',
    'ID': 'count'
})

# Rename the columns for clarity
grouped_df = grouped_df.rename(columns={
    'Quantity': 'TotalQuantity',
    'Discount': 'MeanDiscount',
    'UnitPrice': 'MeanUnitPrice',
    'ID': 'TotalSales'
})

# %%
grouped_df
# Out:
#                                    TotalQuantity  MeanDiscount  MeanUnitPrice  \
# ProductID
# 00066f42aeeb9f3007548bb9d3f33c381            260      0.093252          194.6
# 00066f42aeeb9f3007548bb9d3f33c382            222      0.092019          194.6
# 00066f42aeeb9f3007548bb9d3f33c383            927      0.092816          194.6
# 00088930e925c41fd95ebfe695fd26551            225      0.092264          117.6
# 00088930e925c41fd95ebfe695fd26552            211      0.093073          117.6
# ...                                          ...           ...            ...
# 0030e635639c898b323826589761cf233            953      0.092856          190.4
# 003128f981470c3e5a2e7445e4a771cd1            230      0.092986          161.0
# 003128f981470c3e5a2e7445e4a771cd2            254      0.092131          161.0
# 003128f981470c3e5a2e7445e4a771cd3            549      0.092724          161.0
# 003128f981470c3e5a2e7445e4a771cd4            432      0.093881          161.0
#
# ...

# %%
grouped_df.sort_values(by='TotalQuantity')
# Out:
#                                    TotalQuantity  MeanDiscount  MeanUnitPrice  \
# ProductID
# 001b237c0e9bb435f2e54071129237e92            201      0.092893          162.4
# 00088930e925c41fd95ebfe695fd26552            211      0.093073          117.6
# 002552c0663708129c0019cc97552d7d2            214      0.092500          249.2
# 00210e41887c2a8ef9f791ebc780cc362            214      0.093235          406.0
# 00126f27c813603687e6ce486d909d012            216      0.091754          114.8
# ...                                          ...           ...            ...
# 0011c512eb256aa0dbbb544d8dffcf6e3            996      0.093340          204.4
# 001c5d71ac6ad696d22315953758fa043            996      0.093623          226.8
# 0009406fd7479715e4bef61dd91f24623            998      0.092513          254.8
# 002d4ea7c04739c130bb74d7e7cd16943           1018      0.092648          210.0
# 002ec297b1b00fb9dde7ee6ac24b67713           1020      0.092774          218.4
#
# ...

# %%
002ec297b1b00fb9dde7ee6ac24b67713

# %%
df_produtos = pd.read_csv("Base de Dados - Questionário.xlsx - Sheet2.csv")

# %%
df_produtos[df_produtos["ID"] == "002ec297b1b00fb9dde7ee6ac24b67713"]
# Out:
#                                    ID     Name Size
# 62  002ec297b1b00fb9dde7ee6ac24b67713  Bazinga    G

# %%
df_produtos[df_produtos["Name"] == "Iron Man"]
# Out:
#                                    ID      Name Size
# 57  002d4ea7c04739c130bb74d7e7cd16941  Iron Man    P
# 58  002d4ea7c04739c130bb74d7e7cd16942  Iron Man    M
# 59  002d4ea7c04739c130bb74d7e7cd16943  Iron Man    G

# %%
df_produtos[df_produtos["ID"] == "002d4ea7c04739c130bb74d7e7cd16943"]
# Out:
#                                    ID      Name Size
# 59  002d4ea7c04739c130bb74d7e7cd16943  Iron Man    G

# %%
import seaborn as sns
color_pal = sns.color_palette()
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
df[(df["ProductID"] == "002d4ea7c04739c130bb74d7e7cd16943") & ((df.Date > '2019-01-01' ) & (df.Date < '2019-12-31'))].set_index("Date")[["Quantity"]].resample('M').sum().plot(figsize = (15, 5), color = color_pal[0], title = "Quantidade de vendas por mes")
plt.show()

# %%
df_2019 = df[((df.Date >= '2019-01-01' ) & (df.Date <= '2019-12-31'))]

# %%
df_2019
# Out:
#                                      ID                          ProductID  \
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# 5      7ab64f42a8f9ab290e920eed320d7e60  002552c0663708129c0019cc97552d7d3
# 6      b35a771164a9defa3b4767f1b66918b1  002959d7a0b0990fe2d69988affcbc803
# ...                                 ...                                ...
# 32733  0d8ac7eb8e52447e022b8e4a30ff6394  002d4ea7c04739c130bb74d7e7cd16943
# 32739  18a83c7532fc2dc3a10fd55ff3655588  0011c512eb256aa0dbbb544d8dffcf6e1
# 32740  d105b386fa5b4aab107c43ba2760f64b  002552c0663708129c0019cc97552d7d3
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
#
#        ClientID  Discount  UnitPrice  Quantity  StoreID       Date
# ...

# %%
preco_total_mensal = df_2019.set_index("Date")[["UnitPrice"]].resample('M').sum()

# %%
desconto_total_mensal = df_2019.set_index("Date")[["Discount"]].resample('M').sum()

# %%
df_2019
# Out:
#                                      ID                          ProductID  \
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# 5      7ab64f42a8f9ab290e920eed320d7e60  002552c0663708129c0019cc97552d7d3
# 6      b35a771164a9defa3b4767f1b66918b1  002959d7a0b0990fe2d69988affcbc803
# ...                                 ...                                ...
# 32733  0d8ac7eb8e52447e022b8e4a30ff6394  002d4ea7c04739c130bb74d7e7cd16943
# 32739  18a83c7532fc2dc3a10fd55ff3655588  0011c512eb256aa0dbbb544d8dffcf6e1
# 32740  d105b386fa5b4aab107c43ba2760f64b  002552c0663708129c0019cc97552d7d3
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
#
#        ClientID  Discount  UnitPrice  Quantity  StoreID       Date
# ...

# %%
preco_total_mensal["UnitPrice"]
# Out:
# Date
# 2019-01-31    224638.4
# 2019-02-28    178669.4
# 2019-03-31    303454.2
# 2019-04-30    277320.4
# 2019-05-31    300983.2
# 2019-06-30    471296.0
# 2019-07-31    263993.8
# 2019-08-31    468384.0
# 2019-09-30    269924.2
# 2019-10-31    235551.4
# 2019-11-30    266163.8
# 2019-12-31    455411.6
# Freq: M, Name: UnitPrice, dtype: float64

# %%
desconto_total_mensal
# Out:
#             Discount
# Date
# 2019-01-31    101.20
# 2019-02-28     80.00
# 2019-03-31    115.10
# 2019-04-30    104.20
# 2019-05-31    111.90
# 2019-06-30    152.80
# 2019-07-31    100.60
# 2019-08-31    153.76
# 2019-09-30    101.10
# 2019-10-31     92.30
# 2019-11-30    103.70
# 2019-12-31    146.80

# %%
receita_liq = preco_total_mensal["UnitPrice"] - desconto_total_mensal["Discount"]

# %%
receita_liq
# Out:
# Date
# 2019-01-31    224537.20
# 2019-02-28    178589.40
# 2019-03-31    303339.10
# 2019-04-30    277216.20
# 2019-05-31    300871.30
# 2019-06-30    471143.20
# 2019-07-31    263893.20
# 2019-08-31    468230.24
# 2019-09-30    269823.10
# 2019-10-31    235459.10
# 2019-11-30    266060.10
# 2019-12-31    455264.80
# Freq: M, dtype: float64

# %%
178669.4 - 80.00
# Out:
# 178589.4

# %%
receita_liq.describe()
# Out:
# count        12.000000
# mean     309535.578333
# std       99592.537500
# min      178589.400000
# 25%      256784.675000
# 50%      273519.650000
# 75%      341320.525000
# max      471143.200000
# dtype: float64

# %%
df_2019
# Out:
#                                      ID                          ProductID  \
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# 5      7ab64f42a8f9ab290e920eed320d7e60  002552c0663708129c0019cc97552d7d3
# 6      b35a771164a9defa3b4767f1b66918b1  002959d7a0b0990fe2d69988affcbc803
# ...                                 ...                                ...
# 32733  0d8ac7eb8e52447e022b8e4a30ff6394  002d4ea7c04739c130bb74d7e7cd16943
# 32739  18a83c7532fc2dc3a10fd55ff3655588  0011c512eb256aa0dbbb544d8dffcf6e1
# 32740  d105b386fa5b4aab107c43ba2760f64b  002552c0663708129c0019cc97552d7d3
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
#
#        ClientID  Discount  UnitPrice  Quantity  StoreID       Date
# ...

# %%
df_novo = df_2019.copy()
df_novo["receita liquida"] = df_novo["UnitPrice"] * df_novo["Quantity"] -  df_novo["Discount"]

# %%
df_novo
# Out:
#                                      ID                          ProductID  \
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# 5      7ab64f42a8f9ab290e920eed320d7e60  002552c0663708129c0019cc97552d7d3
# 6      b35a771164a9defa3b4767f1b66918b1  002959d7a0b0990fe2d69988affcbc803
# ...                                 ...                                ...
# 32733  0d8ac7eb8e52447e022b8e4a30ff6394  002d4ea7c04739c130bb74d7e7cd16943
# 32739  18a83c7532fc2dc3a10fd55ff3655588  0011c512eb256aa0dbbb544d8dffcf6e1
# 32740  d105b386fa5b4aab107c43ba2760f64b  002552c0663708129c0019cc97552d7d3
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
#
# ...

# %%
receita_liq_mensal = df_novo.set_index("Date")[["receita liquida"]].resample('M').sum()

# %%
receita_liq_mensal
# Out:
#             receita liquida
# Date
# 2019-01-31        234176.20
# 2019-02-28        187123.80
# 2019-03-31        316644.70
# 2019-04-30        286531.80
# 2019-05-31        314725.70
# 2019-06-30        494129.80
# 2019-07-31        269630.40
# 2019-08-31        495708.04
# 2019-09-30        285242.70
# 2019-10-31        251003.30
# 2019-11-30        275949.70
# 2019-12-31        478661.60

# %%
receita_liq_mensal.describe()
# Out:
#        receita liquida
# count        12.000000
# mean     324127.311667
# std      105654.124979
# min      187123.800000
# 25%      264973.625000
# 50%      285887.250000
# 75%      357148.925000
# max      495708.040000

# %%
df_novo
# Out:
#                                      ID                          ProductID  \
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# 5      7ab64f42a8f9ab290e920eed320d7e60  002552c0663708129c0019cc97552d7d3
# 6      b35a771164a9defa3b4767f1b66918b1  002959d7a0b0990fe2d69988affcbc803
# ...                                 ...                                ...
# 32733  0d8ac7eb8e52447e022b8e4a30ff6394  002d4ea7c04739c130bb74d7e7cd16943
# 32739  18a83c7532fc2dc3a10fd55ff3655588  0011c512eb256aa0dbbb544d8dffcf6e1
# 32740  d105b386fa5b4aab107c43ba2760f64b  002552c0663708129c0019cc97552d7d3
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
#
# ...

# %%
df_novo["receita liquida2"] = df_novo["UnitPrice"] * df_novo["Quantity"] * (1 - df_novo["Discount"])

# %%
df_novo
# Out:
#                                      ID                          ProductID  \
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# 5      7ab64f42a8f9ab290e920eed320d7e60  002552c0663708129c0019cc97552d7d3
# 6      b35a771164a9defa3b4767f1b66918b1  002959d7a0b0990fe2d69988affcbc803
# ...                                 ...                                ...
# 32733  0d8ac7eb8e52447e022b8e4a30ff6394  002d4ea7c04739c130bb74d7e7cd16943
# 32739  18a83c7532fc2dc3a10fd55ff3655588  0011c512eb256aa0dbbb544d8dffcf6e1
# 32740  d105b386fa5b4aab107c43ba2760f64b  002552c0663708129c0019cc97552d7d3
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
#
# ...

# %%
receita_liq_mensal2 = df_novo.set_index("Date")[["receita liquida2"]].resample('M').sum()

# %%
receita_liq_mensal2.describe()
# Out:
#        receita liquida2
# count         12.000000
# mean      294265.094667
# std        99304.561130
# min       168483.420000
# 25%       238564.935000
# 50%       257390.910000
# 75%       323938.797000
# max       456192.856000

# %%
df_novo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14768 entries, 1 to 32751
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                14768 non-null  object
#  1   ProductID         14768 non-null  object
#  2   ClientID          14768 non-null  int64
#  3   Discount          14768 non-null  float64
#  4   UnitPrice         14768 non-null  float64
#  5   Quantity          14768 non-null  int64
#  6   StoreID           14768 non-null  int64
#  7   Date              14768 non-null  datetime64[ns]
#  8   receita liquida   14768 non-null  float64
#  9   receita liquida2  14768 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(2)
# memory usage: 1.2+ MB

# %%
df_novo[df_novo["StoreID"] == 4].set_index("Date")[["receita liquida", "receita liquida2"]].resample('M').sum().describe()
# Out:
#        receita liquida  receita liquida2
# count        12.000000         12.000000
# mean      51448.308333      46692.174667
# std       14892.319929      14037.916079
# min       36026.100000      32436.180000
# 25%       40495.150000      36459.990000
# 50%       47333.850000      42616.350000
# 75%       59060.495000      53539.801000
# max       75736.720000      69698.832000

# %%
lista_lojas = [1,2,3,4,7,9,22]
df_list = []
for i in lista_lojas:
    df_list.append(df_novo[df_novo["StoreID"] == i].set_index("Date")[["receita liquida", "receita liquida2"]].resample('M').sum().describe())

# %%
df_list[0]#loja 1
# Out:
#        receita liquida  receita liquida2
# count        12.000000         12.000000
# mean      82642.726667      75009.713333
# std       25491.989828      23953.401954
# min       42597.200000      38353.140000
# 25%       72030.275000      64851.570000
# 50%       75283.300000      67779.180000
# 75%       90955.900000      82462.121000
# max      128782.200000     118515.320000

# %%
df_list[1]# loja 2
# Out:
#        receita liquida  receita liquida2
# count         12.00000          12.00000
# mean       66395.96500       60283.46800
# std        22107.80031       20777.94279
# min        38309.20000       34493.76000
# 25%        56137.22500       50542.38000
# 50%        59536.20000       53601.03000
# 75%        70013.22500       63520.71600
# max       108197.52000       99572.70400

# %%
df_list[2]# loja 3
# Out:
#        receita liquida  receita liquida2
# count        12.000000         12.000000
# mean      61320.780000      55671.312667
# std       20593.922212      19313.244012
# min       35588.800000      32044.320000
# 25%       49287.275000      44375.310000
# 50%       54524.950000      49089.600000
# 75%       72626.120000      65831.297000
# max       97930.640000      90123.936000

# %%
df_list[3]# loja 4
# Out:
#        receita liquida  receita liquida2
# count        12.000000         12.000000
# mean      51448.308333      46692.174667
# std       14892.319929      14037.916079
# min       36026.100000      32436.180000
# 25%       40495.150000      36459.990000
# 50%       47333.850000      42616.350000
# 75%       59060.495000      53539.801000
# max       75736.720000      69698.832000

# %%
df_list[4]# loja 7
# Out:
#        receita liquida  receita liquida2
# count        12.000000         12.000000
# mean      35285.455000      32056.306333
# std       14237.588565      13314.489018
# min       20964.700000      18876.060000
# 25%       26139.100000      23534.910000
# 50%       28093.550000      25293.240000
# 75%       41696.950000      37810.332000
# max       60339.600000      55528.256000

# %%
df_list[5]# loja 9
# Out:
#        receita liquida  receita liquida2
# count        12.000000         12.000000
# mean      17666.791667      16041.221000
# std        6521.050114       6087.548454
# min        9028.300000       8129.520000
# 25%       13120.325000      11813.130000
# 50%       15670.200000      14108.850000
# 75%       22112.525000      20035.918000
# max       29836.000000      27457.584000

# %%
df_list[6]# loja 22
# Out:
#        receita liquida  receita liquida2
# count        12.000000         12.000000
# mean       9367.285000       8510.898667
# std        4286.246458       3980.029569
# min        3831.200000       3449.880000
# 25%        6489.175000       5842.620000
# 50%        8724.650000       7854.840000
# 75%       11471.300000      10400.600000
# max       16084.320000      14801.696000

# %%
df_novo[df_novo["StoreID"] == 1].set_index("Date")[["receita liquida", "receita liquida2"]].resample('M').sum()
# Out:
#             receita liquida  receita liquida2
# Date
# 2019-01-31         59355.50         53442.900
# 2019-02-28         42597.20         38353.140
# 2019-03-31         77283.90         69580.980
# 2019-04-30         74853.60         67393.620
# 2019-05-31         83055.80         74777.220
# 2019-06-30        119595.12        110062.176
# 2019-07-31         72435.10         65216.340
# 2019-08-31        128782.20        118515.320
# 2019-09-30         75713.00         68164.740
# 2019-10-31         70815.80         63757.260
# 2019-11-30         72569.30         65336.040
# 2019-12-31        114656.20        105516.824

# %%
df_novo
# Out:
#                                      ID                          ProductID  \
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# 5      7ab64f42a8f9ab290e920eed320d7e60  002552c0663708129c0019cc97552d7d3
# 6      b35a771164a9defa3b4767f1b66918b1  002959d7a0b0990fe2d69988affcbc803
# ...                                 ...                                ...
# 32733  0d8ac7eb8e52447e022b8e4a30ff6394  002d4ea7c04739c130bb74d7e7cd16943
# 32739  18a83c7532fc2dc3a10fd55ff3655588  0011c512eb256aa0dbbb544d8dffcf6e1
# 32740  d105b386fa5b4aab107c43ba2760f64b  002552c0663708129c0019cc97552d7d3
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
#
# ...

# %%
df_novo.groupby("StoreID")["receita liquida"].sum()
# Out:
# StoreID
# 1     991712.72
# 2     796751.58
# 3     735849.36
# 4     617379.70
# 7     423425.46
# 9     212001.50
# 22    112407.42
# Name: receita liquida, dtype: float64

# %%
df_novo.groupby("StoreID")["receita liquida2"].sum()
# Out:
# StoreID
# 1     900116.560
# 2     723401.616
# 3     668055.752
# 4     560306.096
# 7     384675.676
# 9     192494.652
# 22    102130.784
# Name: receita liquida2, dtype: float64

# %%
df_novo
# Out:
#                                      ID                          ProductID  \
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# 5      7ab64f42a8f9ab290e920eed320d7e60  002552c0663708129c0019cc97552d7d3
# 6      b35a771164a9defa3b4767f1b66918b1  002959d7a0b0990fe2d69988affcbc803
# ...                                 ...                                ...
# 32733  0d8ac7eb8e52447e022b8e4a30ff6394  002d4ea7c04739c130bb74d7e7cd16943
# 32739  18a83c7532fc2dc3a10fd55ff3655588  0011c512eb256aa0dbbb544d8dffcf6e1
# 32740  d105b386fa5b4aab107c43ba2760f64b  002552c0663708129c0019cc97552d7d3
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
#
# ...

# %%
import pandas as pd

# Assuming your sales data is in a DataFrame named 'sales_data' with columns: 'StoreID', 'Date', and 'SalesRevenue'

# Group the sales data by store and date, and calculate monthly sales
monthly_sales = df_novo.groupby(['StoreID', pd.Grouper(key='Date', freq='M')])['receita liquida'].sum().reset_index()

# Calculate outliers for each store's monthly sales
outliers = pd.DataFrame()
for store_id, store_group in monthly_sales.groupby('StoreID'):
    q1 = store_group['receita liquida'].quantile(0.25)
    q3 = store_group['receita liquida'].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    store_outliers = store_group[(store_group['receita liquida'] < lower_bound) | (store_group['receita liquida'] > upper_bound)]
    outliers = pd.concat([outliers, store_outliers])

# Print the outliers for each store's monthly sales
print(outliers)
# Out:
#     StoreID       Date  receita liquida
# 1         1 2019-02-28         42597.20
# 5         1 2019-06-30        119595.12
# 7         1 2019-08-31        128782.20
# 17        2 2019-06-30         97885.16
# 19        2 2019-08-31        108197.52
# 23        2 2019-12-31         97436.00

# %%
outliers
# Out:
#     StoreID       Date  receita liquida
# 1         1 2019-02-28         42597.20
# 5         1 2019-06-30        119595.12
# 7         1 2019-08-31        128782.20
# 17        2 2019-06-30         97885.16
# 19        2 2019-08-31        108197.52
# 23        2 2019-12-31         97436.00
